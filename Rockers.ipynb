# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0430/VITBML-EDA1/blob/master/Rockers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**TEAM MEMBERS:**
# * 19PA1A0402-A.TEJESWINI
# * 19PA1A0403-A.SAMHITHA
# * 19PA1A0404-A.SUDHA
# * 19PA1A0430-Ch.YASWANTH

# %% [markdown]
# #**DESCRIPTION:**
# * The below data type is about hotel managment about how the people uses the hotel,and at what timing people uses to stay more at hotels.
# * The below given data is consists of 10,233 rows and 11 coloumns.
# * The data is divided as per adults and children.
# * The given data is divided as per how many people are staying in a week,month,year.
# * And how many people stays in weekend nights and week nights.

# %% [markdown]
# #**QUESTIONS:**
# * #How to fill missing values
# * #How to get data types of columns
# * #How to set a column as a index
# * #How to drop a colum or a row
# * #How to find shape of data set
# * #How to get features of a row

# %% [markdown]
# *
# This code reads the data in the uploaded file.

# %%
import pandas as pd
a=pd.read_excel("/content/hotel managment.xlsx")
print(a)
# Out:
#               hotel  is_canceled  ...  adults  children
# 0      Resort Hotel            0  ...       2         0
# 1      Resort Hotel            0  ...       2         0
# 2      Resort Hotel            0  ...       1         0
# 3      Resort Hotel            0  ...       1         0
# 4      Resort Hotel            0  ...       2         0
# ...             ...          ...  ...     ...       ...
# 10228  Resort Hotel            1  ...       2         0
# 10229  Resort Hotel            1  ...       2         0
# 10230  Resort Hotel            1  ...       2         0
# 10231  Resort Hotel            1  ...       2         0
# 10232  Resort Hotel            1  ...       2         0
#
# [10233 rows x 11 columns]

# %% [markdown]
# * The given code describes the nunber of rows and coloums in the data set.

# %%
a.shape
# Out:
# (10233, 11)

# %% [markdown]
# * This code gives you a data of a particular values of a single coloum value.

# %%
print(a.loc[1])
# Out:
# hotel                        Resort Hotel
# is_canceled                             0
# lead_time                             737
# arrival_date_year                    2015
# arrival_date_month                   July
# arrival_date_week_number               27
# arrival_date_day_of_month               1
# stays_in_weekend_nights                 0
# stays_in_week_nights                    0
# adults                                  2
# children                                0
# Name: 1, dtype: object

# %% [markdown]
# * The given data is converted into a bar graph.

# %%
import matplotlib.pyplot as plt
b=a.tail(5)
b.plot(kind="bar")
plt.show()

# %% [markdown]
# * This code identifies the NaN values in the given data set.

# %%
import numpy as np
b=a.iloc[0:10,0:5]
b.iloc[0:3,0:4]=np.nan
print(b)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month
# 0           NaN          NaN        NaN                NaN               July
# 1           NaN          NaN        NaN                NaN               July
# 2           NaN          NaN        NaN                NaN               July
# 3  Resort Hotel          0.0       13.0             2015.0               July
# 4  Resort Hotel          0.0       14.0             2015.0               July
# 5  Resort Hotel          0.0       14.0             2015.0               July
# 6  Resort Hotel          0.0        0.0             2015.0               July
# 7  Resort Hotel          0.0        9.0             2015.0               July
# 8  Resort Hotel          1.0       85.0             2015.0               July
# 9  Resort Hotel          1.0       75.0             2015.0               July

# %% [markdown]
# * It describes the dropping of a coloum.

# %%
a.drop(["hotel"],axis=1,inplace=True)
print(a)
# Out:
#        is_canceled  lead_time  ...  adults children
# 0                0        342  ...       2        0
# 1                0        737  ...       2        0
# 2                0          7  ...       1        0
# 3                0         13  ...       1        0
# 4                0         14  ...       2        0
# ...            ...        ...  ...     ...      ...
# 10228            1          0  ...       2        0
# 10229            1          7  ...       2        0
# 10230            1         51  ...       2        0
# 10231            1          2  ...       2        0
# 10232            1         70  ...       2        0
#
# [10233 rows x 10 columns]

# %% [markdown]
# * Here a particular coloum is selected as a index.

# %%
a.set_index("arrival_date_month",inplace=True)
print(a)
# Out:
#                     is_canceled  lead_time  ...  adults  children
# arrival_date_month                          ...
# July                          0        342  ...       2         0
# July                          0        737  ...       2         0
# July                          0          7  ...       1         0
# July                          0         13  ...       1         0
# July                          0         14  ...       2         0
# ...                         ...        ...  ...     ...       ...
# February                      1          0  ...       2         0
# February                      1          7  ...       2         0
# February                      1         51  ...       2         0
# February                      1          2  ...       2         0
# February                      1         70  ...       2         0
#
# [10233 rows x 9 columns]

# %% [markdown]
# * The given code is used to replace NaN values.

# %%
a.iloc[1:2,0:2]=np.nan
v=a.fillna("sweet magic")
print(v)
# Out:
#                     is_canceled    lead_time  ...  adults  children
# arrival_date_month                            ...
# July                          0          342  ...       2         0
# July                sweet magic  sweet magic  ...       2         0
# July                          0            7  ...       1         0
# July                          0           13  ...       1         0
# July                          0           14  ...       2         0
# ...                         ...          ...  ...     ...       ...
# February                      1            0  ...       2         0
# February                      1            7  ...       2         0
# February                      1           51  ...       2         0
# February                      1            2  ...       2         0
# February                      1           70  ...       2         0
#
# [10233 rows x 9 columns]

# %% [markdown]
# * a.info() gives the information of a given data set.

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10233 entries, July to February
# Data columns (total 9 columns):
# is_canceled                  10232 non-null float64
# lead_time                    10232 non-null float64
# arrival_date_year            10233 non-null int64
# arrival_date_week_number     10233 non-null int64
# arrival_date_day_of_month    10233 non-null int64
# stays_in_weekend_nights      10233 non-null int64
# stays_in_week_nights         10233 non-null int64
# adults                       10233 non-null int64
# children                     10233 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 799.5+ KB

# %% [markdown]
# * The above data is changed into seaborn.

# %%
import seaborn as sns
sns.pairplot(data=a)

# %% [markdown]
# * The data is explained through the below code.

# %%
a.describe()
# Out:
#         is_canceled     lead_time  ...        adults      children
# count  10232.000000  10232.000000  ...  10233.000000  10233.000000
# mean       0.641810    114.116888  ...      1.940780      0.129581
# std        0.479492     96.730340  ...      1.129259      0.458839
# min        0.000000      0.000000  ...      0.000000      0.000000
# 25%        0.000000     37.000000  ...      2.000000      0.000000
# 50%        1.000000     89.000000  ...      2.000000      0.000000
# 75%        1.000000    169.000000  ...      2.000000      0.000000
# max        1.000000    709.000000  ...     55.000000     10.000000
#
# [8 rows x 9 columns]

# %%
import seaborn as sns
sns.regplot(x=a['arrival_date_year'],y=a['arrival_date_week_number'],fit_reg=True)
